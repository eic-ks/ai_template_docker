# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 2.5.0
# 3.0.3

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier

X, y = load_iris(return_X_y=True)

clf = RandomForestClassifier(random_state=42)
clf.fit(X, y)

print(f"Accuracy: {clf.score(X, y):.3f}")
# Out:
# Accuracy: 1.000

# %%
import kaggle


print(kaggle.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import kaggle
#       2
#       3
#       4 print(kaggle.__version__)
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kaggle/__init__.py:3
#       1 # coding=utf-8
#       2 from __future__ import absolute_import
# ----> 3 from kaggle.api.kaggle_api_extended import KaggleApi
#       5 __version__ = "2.2.3"
#       7 api = KaggleApi()
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:59
#      56 from packaging.version import parse
#      58 import kaggle
# ---> 59 from kagglesdk import get_access_token_from_env, KaggleClient, KaggleCredentials, KaggleEnv, KaggleOAuth  # type: ignore[attr-defined]
#      60 from kagglesdk.admin.types.inbox_file_service import CreateInboxFileRequest
#      61 from kagglesdk.blobs.types.blob_api_service import ApiStartBlobUploadRequest, ApiStartBlobUploadResponse, ApiBlobType
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kagglesdk/__init__.py:3
#       1 __version__ = "0.1.32"
# ----> 3 from kagglesdk.kaggle_client import KaggleClient
#       4 from kagglesdk.kaggle_creds import KaggleCredentials
#       5 from kagglesdk.kaggle_env import get_access_token_from_env, KaggleEnv
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kagglesdk/kaggle_client.py:7
#       5 from kagglesdk.blobs.services.blob_api_service import BlobApiClient
#       6 from kagglesdk.common.services.operations_service import OperationsClient
# ----> 7 from kagglesdk.competitions.services.competition_api_service import CompetitionApiClient
#       8 from kagglesdk.competitions.services.hackathon_api_service import HackathonApiClient
#       9 from kagglesdk.datasets.services.dataset_api_service import DatasetApiClient
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kagglesdk/competitions/services/competition_api_service.py:3
#       1 from kagglesdk.common.types.file_download import FileDownload
#       2 from kagglesdk.common.types.http_redirect import HttpRedirect
# ----> 3 from kagglesdk.competitions.types.competition_api_service import ApiCompetition, ApiCompetitionPage, ApiCreateCodeSubmissionRequest, ApiCreateCodeSubmissionResponse, ApiCreateCompetitionDataRequest, ApiCreateCompetitionDataResponse, ApiCreateCompetitionPageRequest, ApiCreateCompetitionRequest, ApiCreateCompetitionResponse, ApiCreateSubmissionRequest, ApiCreateSubmissionResponse, ApiDeleteCompetitionPageRequest, ApiDownloadDataFileRequest, ApiDownloadDataFilesRequest, ApiDownloadLeaderboardRequest, ApiGetCompetitionDataFilesSummaryRequest, ApiGetCompetitionRequest, ApiGetEpisodeAgentLogsRequest, ApiGetEpisodeReplayRequest, ApiGetLeaderboardRequest, ApiGetLeaderboardResponse, ApiGetSubmissionRequest, ApiLaunchCompetitionRequest, ApiListCompetitionPagesRequest, ApiListCompetitionPagesResponse, ApiListCompetitionsRequest, ApiListCompetitionsResponse, ApiListCompetitionTopicsRequest, ApiListCompetitionTopicsResponse, ApiListDataFilesRequest, ApiListDataFilesResponse, ApiListDataTreeFilesRequest, ApiListSubmissionEpisodesRequest, ApiListSubmissionEpisodesResponse, ApiListSubmissionsRequest, ApiListSubmissionsResponse, ApiListTeamPublicSubmissionsRequest, ApiListTeamPublicSubmissionsResponse, ApiListTopicMessagesRequest, ApiListTopicMessagesResponse, ApiStartSubmissionUploadRequest, ApiStartSubmissionUploadResponse, ApiSubmission, ApiUpdateCompetitionPageRequest, ApiUpdateCompetitionSettingsRequest
#       4 from kagglesdk.competitions.types.host_service import CompetitionSettings
#       5 from kagglesdk.datasets.databundles.types.databundle_api_types import ApiDirectoryContent, ApiFilesSummary
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kagglesdk/competitions/types/competition_api_service.py:6
#       4 from kagglesdk.competitions.types.competition_enums import CompetitionDatabundleType, CompetitionListTab, CompetitionPrivacy, CompetitionSortBy, HostSegment, SubmissionGroup, SubmissionSortBy
#       5 from kagglesdk.competitions.types.episode import EpisodeAgentState, EpisodeState, EpisodeType
# ----> 6 from kagglesdk.competitions.types.host_service import CompetitionSettings
#       7 from kagglesdk.competitions.types.submission_status import SubmissionStatus
#       8 from kagglesdk.discussions.types.discussions_enums import CommentListSortBy, TopicListSortBy
#
# File /workspaces/ai_template/.venv/lib/python3.12/site-packages/kagglesdk/competitions/types/host_service.py:4
#       2 from google.protobuf.field_mask_pb2 import FieldMask
#       3 from kagglesdk.common.types.cropped_image_upload import CroppedImageUpload
# ----> 4 from kagglesdk.competitions.legacy.types.legacy_competition_host_service import EvaluationMetricParameter
#       5 from kagglesdk.competitions.types.competition import Competition, PubliclyCloneable, Reward
#       6 from kagglesdk.competitions.types.competition_email_invite import CompetitionEmailInvite
#
# ModuleNotFoundError: No module named 'kagglesdk.competitions.legacy'
